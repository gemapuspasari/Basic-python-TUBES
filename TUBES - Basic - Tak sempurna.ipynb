# %%
# import library
import datetime
import random
import math
import os

# welcoming words
print ("Selamat Datang!")
print ("Hai! Aku ChandlerBot :) Asisten virtual pertamamu.")
print ("Siapa namamu?")

nama_saya = input("Nama saya  ")

print ("Hi", nama_saya, "Ada yang bisa saya bantu?")

# menu awal
def menu_awal():
  print(" ---MENU UTAMA--- ")
  print("a. Kalkulator")
  print("b. Agenda")
  print("c. Keluar")
print (menu_awal())



# input tanggal
from datetime import date
tanggal = date.today()

# input default
nama = "ChandlerBot"
default = ["Alright! I took the quiz and it turns out I do put career over men.",
         "Yes, on a scale of one to 10, 10 being the dumbest a person can look, you are definitely 19",
         "I'm not great at advice. Can I interest you with a sarcastic comment?",
         "Ok, you have to stop the Q-tip when there's resistance!",
         "What do you know? You're a door. You only like knock knock jokes.",
         "Until I was 25, I thought that the only response to 'I love you' was 'Oh, crap!'"]

message = input ("You: ")

# kalkulator
def add (x,y):
    return x+y
def substract (x,y):
    return x-y
def multiply (x,y):
    return x*y
def divide (x,y):
    return x/y

print ("Pilih operasi")
print ("1. penjumlahan")
print ("2. pengurangan")
print ("3. perkalian")
print ("4. pembagian")
print ("5. end")

while True:
  choice = input ("Operasi 1/2/3/4/end : ")

  if choice in ("1", "2", "3", "4"):
    num1 = float(input("Angka pertama: "))
    num2 = float(input("Angka kedua: "))

    if choice == "1":
      print(num1, "+", num2, "=", add(num1, num2))

    elif choice == "2":
      print(num1, "-", num2, "=", subtract(num1, num2))

    elif choice == "3":
      print(num1, "*", num2, "=", multiply(num1, num2))

    elif choice == "4":
        print(num1, "/", num2, "=", divide(num1, num2))
  else:
      print(menu_awal())

# Agenda

agenda = [
    "Cerita dong. "
    "Curhat babe."
    "I am listening."
]

      
        
# ChatBot

jawaban_nama = [
      "nama saya  {0}".format(nama),
      "orang-orang memanggil saya {0}".format(nama),
      "panggil saja saya {0}".format(nama)
   ]


jawaban_tanggal = [
      "hari ini tanggal {0}".format(tanggal),
      "ya ampun masa tidak tahu, hari ini tanggal {0}".format(tanggal)
    ]

pertanyaan = {
  "nama kamu siapa?": jawaban_nama,
  "kamu siapa?" : jawaban_nama,
  "tanggal berapa hari ini?": jawaban_tanggal,
  "hari ini tanggal berapa?" : jawaban_tanggal,
  "default": default
}

statement =  [
                  'ceritakan lebih banyak!',
                  'kenapa kamu berpikir begitu?',
                  'sudah berapa lama kamu merasa seperti ini?',
                  'Itu sangat menarik!',
                  'oh wow!',
                  ':)'
              ]

responses = {
    'pertanyaan' : pertanyaan,
    'statement' : statement
}

            
def chatbot(message):
    if "siapa" in message or "nama" in message:
      reply = random.choice(jawaban_nama)
    elif "hari" in message or "tanggal" in message:
      reply = random.choice(jawaban_tanggal)
    elif "default" in message:
      reply = random.choice(default)
    elif "b" or "kalkulator" in message:
      reply = kalkulator()
    elif "5" or "keluar" or "end" in message:
      reply = menu_awal()
    elif "b" or "agenda" in message:
      reply = random.choice(agenda)
      break
    else:
       reply = random.choice(statement)
    print('Bot: ' + reply)
while ('end' in message):
  reply = menu_awal()
  message = input('You: ')
  chatbot(message)
# Out:
# Selamat Datang!
# Hai! Aku ChandlerBot :) Asisten virtual pertamamu.
# Siapa namamu?
# Nama saya  gema
# Hi gema Ada yang bisa saya bantu?
#  ---MENU UTAMA---
# a. Kalkulator
# b. Agenda
# c. Keluar
# None
# You: kalkulator
# Pilih operasi
# 1. penjumlahan
# 2. pengurangan
# 3. perkalian
# 4. pembagian
# 5. end
# Operasi 1/2/3/4/end : end
#  ---MENU UTAMA---
# a. Kalkulator
# b. Agenda
# c. Keluar
# None
# Operasi 1/2/3/4/end : agenda
#  ---MENU UTAMA---
# a. Kalkulator
# b. Agenda
# c. Keluar
# None
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# ...
